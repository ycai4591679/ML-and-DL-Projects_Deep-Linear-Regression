# %% [markdown]
# # Regression Exercise
#
# California Housing Data
#
# This data set contains information about all the block groups in California from the 1990 Census. In this sample a block group on average includes 1425.5 individuals living in a geographically compact area.
#
# The task is to aproximate the median house value of each block from the values of the rest of the variables.
#
#  It has been obtained from the LIACC repository. The original page where the data set can be found is: http://www.liaad.up.pt/~ltorgo/Regression/DataSets.html.

# %% [markdown]
# The Features:
#
# * housingMedianAge: continuous.
# * totalRooms: continuous.
# * totalBedrooms: continuous.
# * population: continuous.
# * households: continuous.
# * medianIncome: continuous.
# * medianHouseValue: continuous.

# %% [markdown]
# ## The Data

# %% [markdown]
# ** Import the cal_housing_clean.csv file with pandas. Separate it into a training (70%) and testing set(30%).**

# %%
import pandas as pd

# %%
housing = pd.read_csv('cal_housing_clean.csv')

# %%
housing.head()
# Out:
#    housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 0              41.0       880.0          129.0       322.0       126.0
# 1              21.0      7099.0         1106.0      2401.0      1138.0
# 2              52.0      1467.0          190.0       496.0       177.0
# 3              52.0      1274.0          235.0       558.0       219.0
# 4              52.0      1627.0          280.0       565.0       259.0
#
#    medianIncome  medianHouseValue
# 0        8.3252          452600.0
# 1        8.3014          358500.0
# 2        7.2574          352100.0
# 3        5.6431          341300.0
# 4        3.8462          342200.0

# %%
housing.describe()
# Out:
#        housingMedianAge    totalRooms  totalBedrooms    population  \
# count      20640.000000  20640.000000   20640.000000  20640.000000
# mean          28.639486   2635.763081     537.898014   1425.476744
# std           12.585558   2181.615252     421.247906   1132.462122
# min            1.000000      2.000000       1.000000      3.000000
# 25%           18.000000   1447.750000     295.000000    787.000000
# 50%           29.000000   2127.000000     435.000000   1166.000000
# 75%           37.000000   3148.000000     647.000000   1725.000000
# max           52.000000  39320.000000    6445.000000  35682.000000
#
#          households  medianIncome  medianHouseValue
# count  20640.000000  20640.000000      20640.000000
# mean     499.539680      3.870671     206855.816909
# std      382.329753      1.899822     115395.615874
# min        1.000000      0.499900      14999.000000
# 25%      280.000000      2.563400     119600.000000
# 50%      409.000000      3.534800     179700.000000
# 75%      605.000000      4.743250     264725.000000
# max     6082.000000     15.000100     500001.000000

# %%
housing.describe().transpose()
# Out:
#                     count           mean            std         min  \
# housingMedianAge  20640.0      28.639486      12.585558      1.0000
# totalRooms        20640.0    2635.763081    2181.615252      2.0000
# totalBedrooms     20640.0     537.898014     421.247906      1.0000
# population        20640.0    1425.476744    1132.462122      3.0000
# households        20640.0     499.539680     382.329753      1.0000
# medianIncome      20640.0       3.870671       1.899822      0.4999
# medianHouseValue  20640.0  206855.816909  115395.615874  14999.0000
#
#                           25%          50%           75%          max
# housingMedianAge      18.0000      29.0000      37.00000      52.0000
# totalRooms          1447.7500    2127.0000    3148.00000   39320.0000
# totalBedrooms        295.0000     435.0000     647.00000    6445.0000
# population           787.0000    1166.0000    1725.00000   35682.0000
# households           280.0000     409.0000     605.00000    6082.0000
# medianIncome           2.5634       3.5348       4.74325      15.0001
# medianHouseValue  119600.0000  179700.0000  264725.00000  500001.0000

# %%
x_data = housing.drop(['medianHouseValue'],axis=1)

# %%
y_val = housing['medianHouseValue']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,y_val,test_size=0.3,random_state=101)

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, **options)>

# %% [markdown]
# ### Scale the Feature Data
#
# ** Use sklearn preprocessing to create a MinMaxScaler for the feature data. Fit this scaler only to the training data. Then use it to transform X_test and X_train. Then use the scaled X_test and X_train along with pd.Dataframe to re-create two dataframes of scaled data.**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train.head()
# Out:
#       housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 6761              19.0      2742.0          756.0      1396.0       703.0
# 3010              32.0       444.0          102.0       242.0        87.0
# 7812              35.0       994.0          203.0       602.0       185.0
# 8480              35.0      1281.0          219.0       710.0       184.0
# 1051              16.0      1257.0          231.0       559.0       213.0
#
#       medianIncome
# 6761        2.5663
# 3010        1.1528
# 7812        3.5865
# 8480        4.8304
# 1051        4.4531

# %%
X_train = pd.DataFrame(data=scaler.transform(X_train),columns = X_train.columns,index=X_train.index)

# %%
scaler.transform(X_train) # this is an array, so we need to add column namr and index to make it be a dataFrame
# Out:
# array([[-1.26874279e-02, -4.90948628e-05, -1.37001357e-04,
#         -1.03323552e-04, -1.45462664e-04, -2.46473580e-02],
#        [-7.68935025e-03, -5.05813706e-05, -1.52750854e-04,
#         -1.04738036e-04, -1.62120965e-04, -3.13701214e-02],
#        [-6.53594771e-03, -5.02255920e-05, -1.50318593e-04,
#         -1.04296776e-04, -1.59470781e-04, -1.97951732e-02],
#        ...,
#        [-1.76855056e-02, -4.85877166e-05, -1.41745472e-04,
#         -1.03345615e-04, -1.51195716e-04, -7.62047934e-03],
#        [-6.15148020e-03, -5.03303850e-05, -1.50125938e-04,
#         -1.04366642e-04, -1.58767671e-04, -2.12467384e-02],
#        [-1.11495579e-02, -4.86957439e-05, -1.37747893e-04,
#         -1.02752365e-04, -1.46868884e-04, -2.41451127e-02]])

# %%
X_train.head()
# Out:
#       housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 6761          0.352941    0.069688       0.117163    0.048769    0.115442
# 3010          0.607843    0.011242       0.015673    0.008367    0.014142
# 7812          0.666667    0.025230       0.031347    0.020971    0.030258
# 8480          0.666667    0.032530       0.033830    0.024752    0.030094
# 1051          0.294118    0.031919       0.035692    0.019466    0.034863
#
#       medianIncome
# 6761      0.142508
# 3010      0.045027
# 7812      0.212866
# 8480      0.298651
# 1051      0.272631

# %%
X_train.columns
# Out:
# Index(['housingMedianAge', 'totalRooms', 'totalBedrooms', 'population',
#        'households', 'medianIncome'],
#       dtype='object')

# %%
X_test = pd.DataFrame(data=scaler.transform(X_test),columns = X_test.columns,index=X_test.index)

# %%
X_test.head()
# Out:
#        housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 16086          0.686275    0.046264       0.045158    0.025873    0.048841
# 8816           0.705882    0.027417       0.020795    0.012709    0.023187
# 7175           0.901961    0.032326       0.040813    0.041662    0.042592
# 16714          0.313725    0.043212       0.046089    0.032840    0.048018
# 14491          0.411765    0.088433       0.069367    0.043728    0.072192
#
#        medianIncome
# 16086      0.353133
# 8816       0.770182
# 7175       0.133626
# 16714      0.263576
# 14491      0.660046

# %% [markdown]
# ### Create Feature Columns
#
# ** Create the necessary tf.feature_column objects for the estimator. They should all be trated as continuous numeric_columns. **

# %%
housing.columns
# Out:
# Index(['housingMedianAge', 'totalRooms', 'totalBedrooms', 'population',
#        'households', 'medianIncome', 'medianHouseValue'],
#       dtype='object')

# %%
import tensorflow as tf

# %%
feat_cols = []

for col in X_train.columns:
    feat_cols.append(tf.feature_column.numeric_column(col))

# %%
feat_cols
# Out:
# [NumericColumn(key='housingMedianAge', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='totalRooms', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='totalBedrooms', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='population', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='households', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='medianIncome', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
# age = tf.feature_column.numeric_column('housingMedianAge')
# rooms = tf.feature_column.numeric_column('totalRooms')
# bedrooms = tf.feature_column.numeric_column('totalBedrooms')
# pop = tf.feature_column.numeric_column('population')
# households = tf.feature_column.numeric_column('households')
# income = tf.feature_column.numeric_column('medianIncome')

# %%
#feat_cols = [ age,rooms,bedrooms,pop,households,income]

# %% [markdown]
# ** Create the input function for the estimator object. (play around with batch_size and num_epochs)**

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train ,batch_size=10,num_epochs=2000,
                                            shuffle=True)

# %% [markdown]
# ** Create the estimator model. Use a DNNRegressor. Play around with the hidden units! **

# %%
# DNNRegressor Model
model = tf.estimator.DNNRegressor(hidden_units=[6,20,20,20,6],feature_columns=feat_cols)
# Out:
# W1224 04:36:30.292018 15072 estimator.py:1811] Using temporary folder as model directory: C:\Users\caiyi\AppData\Local\Temp\tmpe6_guk6f

# %%
# model = tf.estimator.LinearRegressor(feature_columns=feat_cols)

# %% [markdown]
# ##### ** Train the model for ~1,000 steps. (Later come back to this and train it for more and check for improvement) **

# %%
model.train(input_fn=input_func,steps=100000)

# %% [markdown]
# ** Create a prediction input function and then use the .predict method off your estimator model to create a list or predictions on your test data. **

# %%
predict_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
pred_gen = model.predict(predict_input_func)

# %%
predictions = list(pred_gen)

# %%
predictions
# Out:
# [{'predictions': array([302276.7], dtype=float32)},
#  {'predictions': array([575035.2], dtype=float32)},
#  {'predictions': array([153980.33], dtype=float32)},
#  {'predictions': array([181540.06], dtype=float32)},
#  {'predictions': array([471675.34], dtype=float32)},
#  {'predictions': array([167812.69], dtype=float32)},
#  {'predictions': array([208207.6], dtype=float32)},
#  {'predictions': array([179542.08], dtype=float32)},
#  {'predictions': array([263810.44], dtype=float32)},
#  {'predictions': array([316753.72], dtype=float32)},
#  {'predictions': array([196532.88], dtype=float32)},
#  {'predictions': array([198508.75], dtype=float32)},
#  {'predictions': array([158275.4], dtype=float32)},
#  {'predictions': array([147387.66], dtype=float32)},
#  {'predictions': array([321627.1], dtype=float32)},
#  {'predictions': array([181128.62], dtype=float32)},
#  {'predictions': array([152919.64], dtype=float32)},
#  {'predictions': array([193885.94], dtype=float32)},
#  {'predictions': array([173817.6], dtype=float32)},
#  {'predictions': array([355275.72], dtype=float32)},
#  {'predictions': array([158570.67], dtype=float32)},
#  {'predictions': array([262915.2], dtype=float32)},
#  {'predictions': array([212054.88], dtype=float32)},
#  {'predictions': array([140632.86], dtype=float32)},
#  {'predictions': array([139919.66], dtype=float32)},
#  {'predictions': array([418198.1], dtype=float32)},
#  {'predictions': array([138293.84], dtype=float32)},
#  {'predictions': array([82987.64], dtype=float32)},
#  {'predictions': array([114326.36], dtype=float32)},
#  {'predictions': array([188634.88], dtype=float32)},
#  {'predictions': array([269221.16], dtype=float32)},
#  {'predictions': array([155317.03], dtype=float32)},
#  {'predictions': array([217126.], dtype=float32)},
#  {'predictions': array([298666.25], dtype=float32)},
#  {'predictions': array([168571.52], dtype=float32)},
#  {'predictions': array([137186.6], dtype=float32)},
#  {'predictions': array([134803.97], dtype=float32)},
#  {'predictions': array([143666.08], dtype=float32)},
#  {'predictions': array([171900.5], dtype=float32)},
#  {'predictions': array([206759.27], dtype=float32)},
#  {'predictions': array([183844.56], dtype=float32)},
#  {'predictions': array([190471.11], dtype=float32)},
#  {'predictions': array([179315.06], dtype=float32)},
#  {'predictions': array([144189.83], dtype=float32)},
#  {'predictions': array([258436.31], dtype=float32)},
#  {'predictions': array([286504.8], dtype=float32)},
#  {'predictions': array([203219.1], dtype=float32)},
#  {'predictions': array([126946.47], dtype=float32)},
#  {'predictions': array([143949.98], dtype=float32)},
#  {'predictions': array([220905.53], dtype=float32)},
#  {'predictions': array([166867.61], dtype=float32)},
#  {'predictions': array([174093.64], dtype=float32)},
#  {'predictions': array([436325.9], dtype=float32)},
#  {'predictions': array([179908.28], dtype=float32)},
#  {'predictions': array([139072.78], dtype=float32)},
#  {'predictions': array([174970.53], dtype=float32)},
#  {'predictions': array([172632.66], dtype=float32)},
#  {'predictions': array([213193.84], dtype=float32)},
#  {'predictions': array([195723.05], dtype=float32)},
#  {'predictions': array([153185.69], dtype=float32)},
#  {'predictions': array([110881.79], dtype=float32)},
#  {'predictions': array([469261.97], dtype=float32)},
#  {'predictions': array([350235.66], dtype=float32)},
#  {'predictions': array([192417.6], dtype=float32)},
#  {'predictions': array([127138.625], dtype=float32)},
#  {'predictions': array([222744.88], dtype=float32)},
#  {'predictions': array([169969.27], dtype=float32)},
#  {'predictions': array([340448.72], dtype=float32)},
#  {'predictions': array([248796.62], dtype=float32)},
#  {'predictions': array([229938.94], dtype=float32)},
#  {'predictions': array([151274.34], dtype=float32)},
#  {'predictions': array([162723.62], dtype=float32)},
#  {'predictions': array([214799.62], dtype=float32)},
#  {'predictions': array([134379.12], dtype=float32)},
#  {'predictions': array([201839.86], dtype=float32)},
#  {'predictions': array([142266.06], dtype=float32)},
#  {'predictions': array([338382.4], dtype=float32)},
#  {'predictions': array([136426.31], dtype=float32)},
#  {'predictions': array([394354.66], dtype=float32)},
#  {'predictions': array([168972.38], dtype=float32)},
#  {'predictions': array([260240.47], dtype=float32)},
#  {'predictions': array([285236.9], dtype=float32)},
#  {'predictions': array([165205.33], dtype=float32)},
#  {'predictions': array([132766.27], dtype=float32)},
#  {'predictions': array([266737.56], dtype=float32)},
#  {'predictions': array([341591.16], dtype=float32)},
#  {'predictions': array([86652.35], dtype=float32)},
#  {'predictions': array([117887.95], dtype=float32)},
#  {'predictions': array([256619.6], dtype=float32)},
#  {'predictions': array([369919.1], dtype=float32)},
#  {'predictions': array([155113.38], dtype=float32)},
#  {'predictions': array([113243.086], dtype=float32)},
#  {'predictions': array([106210.06], dtype=float32)},
#  {'predictions': array([139376.47], dtype=float32)},
#  {'predictions': array([175066.78], dtype=float32)},
#  {'predictions': array([179699.05], dtype=float32)},
#  {'predictions': array([271115.72], dtype=float32)},
#  {'predictions': array([579942.5], dtype=float32)},
#  {'predictions': array([109222.66], dtype=float32)},
#  {'predictions': array([140270.88], dtype=float32)},
#  {'predictions': array([168700.34], dtype=float32)},
#  {'predictions': array([349036.9], dtype=float32)},
#  {'predictions': array([336685.88], dtype=float32)},
#  {'predictions': array([181106.34], dtype=float32)},
#  {'predictions': array([224874.88], dtype=float32)},
#  {'predictions': array([207642.86], dtype=float32)},
#  {'predictions': array([378713.66], dtype=float32)},
#  {'predictions': array([168650.31], dtype=float32)},
#  {'predictions': array([190797.67], dtype=float32)},
#  {'predictions': array([131401.95], dtype=float32)},
#  {'predictions': array([139914.42], dtype=float32)},
#  {'predictions': array([164851.88], dtype=float32)},
#  {'predictions': array([330032.03], dtype=float32)},
#  {'predictions': array([168943.78], dtype=float32)},
#  {'predictions': array([305742.22], dtype=float32)},
#  {'predictions': array([247152.22], dtype=float32)},
#  {'predictions': array([219646.66], dtype=float32)},
#  {'predictions': array([402424.62], dtype=float32)},
#  {'predictions': array([118161.26], dtype=float32)},
#  {'predictions': array([194726.66], dtype=float32)},
#  {'predictions': array([199353.8], dtype=float32)},
#  {'predictions': array([212342.94], dtype=float32)},
#  {'predictions': array([186161.75], dtype=float32)},
#  {'predictions': array([150105.], dtype=float32)},
#  {'predictions': array([202262.98], dtype=float32)},
#  {'predictions': array([111651.57], dtype=float32)},
#  {'predictions': array([269616.], dtype=float32)},
#  {'predictions': array([252405.78], dtype=float32)},
#  {'predictions': array([283322.62], dtype=float32)},
#  {'predictions': array([195949.02], dtype=float32)},
#  {'predictions': array([162938.6], dtype=float32)},
#  {'predictions': array([171111.69], dtype=float32)},
#  {'predictions': array([139355.31], dtype=float32)},
#  {'predictions': array([301514.4], dtype=float32)},
#  {'predictions': array([108653.79], dtype=float32)},
#  {'predictions': array([170946.86], dtype=float32)},
#  {'predictions': array([298392.6], dtype=float32)},
#  {'predictions': array([81642.016], dtype=float32)},
#  {'predictions': array([302441.2], dtype=float32)},
#  {'predictions': array([271513.22], dtype=float32)},
#  {'predictions': array([194245.84], dtype=float32)},
#  {'predictions': array([249643.38], dtype=float32)},
#  {'predictions': array([301660.34], dtype=float32)},
#  {'predictions': array([215780.58], dtype=float32)},
#  {'predictions': array([203319.23], dtype=float32)},
#  {'predictions': array([181852.14], dtype=float32)},
#  {'predictions': array([152718.66], dtype=float32)},
#  {'predictions': array([238087.75], dtype=float32)},
#  {'predictions': array([114185.61], dtype=float32)},
#  {'predictions': array([342532.1], dtype=float32)},
#  {'predictions': array([269274.47], dtype=float32)},
#  {'predictions': array([81959.04], dtype=float32)},
#  {'predictions': array([263554.97], dtype=float32)},
#  {'predictions': array([226689.6], dtype=float32)},
#  {'predictions': array([146008.61], dtype=float32)},
#  {'predictions': array([301639.78], dtype=float32)},
#  {'predictions': array([216552.28], dtype=float32)},
#  {'predictions': array([293289.72], dtype=float32)},
#  {'predictions': array([217654.4], dtype=float32)},
#  {'predictions': array([182883.47], dtype=float32)},
#  {'predictions': array([117549.07], dtype=float32)},
#  {'predictions': array([497555.94], dtype=float32)},
#  {'predictions': array([235202.11], dtype=float32)},
#  {'predictions': array([125624.75], dtype=float32)},
#  {'predictions': array([204904.39], dtype=float32)},
#  {'predictions': array([254367.6], dtype=float32)},
#  {'predictions': array([117092.54], dtype=float32)},
#  {'predictions': array([219487.19], dtype=float32)},
#  {'predictions': array([112328.23], dtype=float32)},
#  {'predictions': array([503176.72], dtype=float32)},
#  {'predictions': array([243152.38], dtype=float32)},
#  {'predictions': array([163905.44], dtype=float32)},
#  {'predictions': array([140320.88], dtype=float32)},
#  {'predictions': array([130747.73], dtype=float32)},
#  {'predictions': array([133980.25], dtype=float32)},
#  {'predictions': array([127986.82], dtype=float32)},
#  {'predictions': array([248510.14], dtype=float32)},
#  {'predictions': array([132775.66], dtype=float32)},
#  {'predictions': array([235579.05], dtype=float32)},
#  {'predictions': array([136925.6], dtype=float32)},
#  {'predictions': array([114294.016], dtype=float32)},
#  {'predictions': array([127713.88], dtype=float32)},
#  {'predictions': array([303391.28], dtype=float32)},
#  {'predictions': array([109962.305], dtype=float32)},
#  {'predictions': array([160818.88], dtype=float32)},
#  {'predictions': array([112491.6], dtype=float32)},
#  {'predictions': array([146293.23], dtype=float32)},
#  {'predictions': array([228479.31], dtype=float32)},
#  {'predictions': array([124027.85], dtype=float32)},
#  {'predictions': array([109486.88], dtype=float32)},
#  {'predictions': array([265365.75], dtype=float32)},
#  {'predictions': array([173384.53], dtype=float32)},
#  {'predictions': array([391633.97], dtype=float32)},
#  {'predictions': array([156743.42], dtype=float32)},
#  {'predictions': array([194049.31], dtype=float32)},
#  {'predictions': array([297413.72], dtype=float32)},
#  {'predictions': array([291958.97], dtype=float32)},
#  {'predictions': array([149658.5], dtype=float32)},
#  {'predictions': array([192766.94], dtype=float32)},
#  {'predictions': array([128796.914], dtype=float32)},
#  {'predictions': array([110013.1], dtype=float32)},
#  {'predictions': array([162063.81], dtype=float32)},
#  {'predictions': array([250935.84], dtype=float32)},
#  {'predictions': array([184857.66], dtype=float32)},
#  {'predictions': array([739868.1], dtype=float32)},
#  {'predictions': array([230789.1], dtype=float32)},
#  {'predictions': array([263018.47], dtype=float32)},
#  {'predictions': array([284798.84], dtype=float32)},
#  {'predictions': array([137940.3], dtype=float32)},
#  {'predictions': array([201588.4], dtype=float32)},
#  {'predictions': array([136039.1], dtype=float32)},
#  {'predictions': array([245908.53], dtype=float32)},
#  {'predictions': array([225649.94], dtype=float32)},
#  {'predictions': array([289063.84], dtype=float32)},
#  {'predictions': array([110659.555], dtype=float32)},
#  {'predictions': array([141015.84], dtype=float32)},
#  {'predictions': array([244532.25], dtype=float32)},
#  {'predictions': array([126011.23], dtype=float32)},
#  {'predictions': array([286226.1], dtype=float32)},
#  {'predictions': array([211727.22], dtype=float32)},
#  {'predictions': array([144625.27], dtype=float32)},
#  {'predictions': array([385443.1], dtype=float32)},
#  {'predictions': array([179404.1], dtype=float32)},
#  {'predictions': array([172041.05], dtype=float32)},
#  {'predictions': array([166665.11], dtype=float32)},
#  {'predictions': array([390003.53], dtype=float32)},
#  {'predictions': array([190323.4], dtype=float32)},
#  {'predictions': array([107946.086], dtype=float32)},
#  {'predictions': array([152333.33], dtype=float32)},
#  {'predictions': array([242391.53], dtype=float32)},
#  {'predictions': array([304808.6], dtype=float32)},
#  {'predictions': array([117262.336], dtype=float32)},
#  {'predictions': array([140795.83], dtype=float32)},
#  {'predictions': array([112730.35], dtype=float32)},
#  {'predictions': array([168373.8], dtype=float32)},
#  {'predictions': array([317590.9], dtype=float32)},
#  {'predictions': array([402905.06], dtype=float32)},
#  {'predictions': array([203301.97], dtype=float32)},
#  {'predictions': array([328543.1], dtype=float32)},
#  {'predictions': array([243370.02], dtype=float32)},
#  {'predictions': array([331858.3], dtype=float32)},
#  {'predictions': array([260190.25], dtype=float32)},
#  {'predictions': array([361813.34], dtype=float32)},
#  {'predictions': array([157488.12], dtype=float32)},
#  {'predictions': array([253680.72], dtype=float32)},
#  {'predictions': array([132409.08], dtype=float32)},
#  {'predictions': array([254219.12], dtype=float32)},
#  {'predictions': array([191062.86], dtype=float32)},
#  {'predictions': array([238029.16], dtype=float32)},
#  {'predictions': array([234767.84], dtype=float32)},
#  {'predictions': array([206072.94], dtype=float32)},
#  {'predictions': array([231272.9], dtype=float32)},
#  {'predictions': array([116133.984], dtype=float32)},
#  {'predictions': array([160734.53], dtype=float32)},
#  {'predictions': array([127908.66], dtype=float32)},
#  {'predictions': array([148352.66], dtype=float32)},
#  {'predictions': array([155604.9], dtype=float32)},
#  {'predictions': array([123607.18], dtype=float32)},
#  {'predictions': array([209745.56], dtype=float32)},
#  {'predictions': array([184058.03], dtype=float32)},
#  {'predictions': array([138086.61], dtype=float32)},
#  {'predictions': array([181888.25], dtype=float32)},
#  {'predictions': array([382903.16], dtype=float32)},
#  {'predictions': array([116394.67], dtype=float32)},
#  {'predictions': array([317612.9], dtype=float32)},
#  {'predictions': array([347229.4], dtype=float32)},
#  {'predictions': array([279438.44], dtype=float32)},
#  {'predictions': array([171968.23], dtype=float32)},
#  {'predictions': array([142170.55], dtype=float32)},
#  {'predictions': array([118690.76], dtype=float32)},
#  {'predictions': array([194892.75], dtype=float32)},
#  {'predictions': array([185266.31], dtype=float32)},
#  {'predictions': array([137781.47], dtype=float32)},
#  {'predictions': array([66491.086], dtype=float32)},
#  {'predictions': array([215471.08], dtype=float32)},
#  {'predictions': array([214097.56], dtype=float32)},
#  {'predictions': array([194233.12], dtype=float32)},
#  {'predictions': array([266867.06], dtype=float32)},
#  {'predictions': array([133206.2], dtype=float32)},
#  {'predictions': array([257257.14], dtype=float32)},
#  {'predictions': array([144586.08], dtype=float32)},
#  {'predictions': array([279338.38], dtype=float32)},
#  {'predictions': array([204696.56], dtype=float32)},
#  {'predictions': array([227796.56], dtype=float32)},
#  {'predictions': array([104382.875], dtype=float32)},
#  {'predictions': array([134024.3], dtype=float32)},
#  {'predictions': array([149175.84], dtype=float32)},
#  {'predictions': array([226475.66], dtype=float32)},
#  {'predictions': array([173656.78], dtype=float32)},
#  {'predictions': array([386878.66], dtype=float32)},
#  {'predictions': array([126903.945], dtype=float32)},
#  {'predictions': array([213832.88], dtype=float32)},
#  {'predictions': array([134302.81], dtype=float32)},
#  {'predictions': array([128121.21], dtype=float32)},
#  {'predictions': array([475974.6], dtype=float32)},
#  {'predictions': array([177736.4], dtype=float32)},
#  {'predictions': array([215392.94], dtype=float32)},
#  {'predictions': array([198608.64], dtype=float32)},
#  {'predictions': array([393357.03], dtype=float32)},
#  {'predictions': array([350218.44], dtype=float32)},
#  {'predictions': array([210228.08], dtype=float32)},
#  {'predictions': array([129165.82], dtype=float32)},
#  {'predictions': array([187002.17], dtype=float32)},
#  {'predictions': array([186539.34], dtype=float32)},
#  {'predictions': array([602846.6], dtype=float32)},
#  {'predictions': array([252362.38], dtype=float32)},
#  {'predictions': array([226163.31], dtype=float32)},
#  {'predictions': array([356082.38], dtype=float32)},
#  {'predictions': array([188236.61], dtype=float32)},
#  {'predictions': array([159687.61], dtype=float32)},
#  {'predictions': array([88406.07], dtype=float32)},
#  {'predictions': array([356700.9], dtype=float32)},
#  {'predictions': array([250890.9], dtype=float32)},
#  {'predictions': array([258757.28], dtype=float32)},
#  {'predictions': array([171939.03], dtype=float32)},
#  {'predictions': array([112685.38], dtype=float32)},
#  {'predictions': array([202417.58], dtype=float32)},
#  {'predictions': array([145649.6], dtype=float32)},
#  {'predictions': array([130078.33], dtype=float32)},
#  {'predictions': array([117544.9], dtype=float32)},
#  {'predictions': array([287138.72], dtype=float32)},
#  {'predictions': array([175452.38], dtype=float32)},
#  {'predictions': array([117046.73], dtype=float32)},
#  {'predictions': array([186262.5], dtype=float32)},
#  {'predictions': array([120307.68], dtype=float32)},
#  {'predictions': array([278596.22], dtype=float32)},
#  {'predictions': array([115982.29], dtype=float32)},
#  {'predictions': array([134815.58], dtype=float32)},
#  {'predictions': array([137191.7], dtype=float32)},
#  {'predictions': array([148123.], dtype=float32)},
#  {'predictions': array([177361.16], dtype=float32)},
#  {'predictions': array([236876.31], dtype=float32)},
#  {'predictions': array([137721.55], dtype=float32)},
#  {'predictions': array([140223.75], dtype=float32)},
#  {'predictions': array([213337.], dtype=float32)},
#  {'predictions': array([179036.94], dtype=float32)},
#  {'predictions': array([166076.34], dtype=float32)},
#  {'predictions': array([317434.97], dtype=float32)},
#  {'predictions': array([214835.28], dtype=float32)},
#  {'predictions': array([231882.7], dtype=float32)},
#  {'predictions': array([159718.1], dtype=float32)},
#  {'predictions': array([149051.14], dtype=float32)},
#  {'predictions': array([149834.06], dtype=float32)},
#  {'predictions': array([108365.6], dtype=float32)},
#  {'predictions': array([236514.9], dtype=float32)},
#  {'predictions': array([402970.53], dtype=float32)},
#  {'predictions': array([127310.305], dtype=float32)},
#  {'predictions': array([227350.97], dtype=float32)},
#  {'predictions': array([177083.69], dtype=float32)},
#  {'predictions': array([102785.98], dtype=float32)},
#  {'predictions': array([162623.], dtype=float32)},
#  {'predictions': array([362932.03], dtype=float32)},
#  {'predictions': array([379430.03], dtype=float32)},
#  {'predictions': array([257057.66], dtype=float32)},
#  {'predictions': array([129051.91], dtype=float32)},
#  {'predictions': array([161529.6], dtype=float32)},
#  {'predictions': array([250984.62], dtype=float32)},
#  {'predictions': array([219845.97], dtype=float32)},
#  {'predictions': array([230683.58], dtype=float32)},
#  {'predictions': array([209465.81], dtype=float32)},
#  {'predictions': array([257472.88], dtype=float32)},
#  {'predictions': array([294524.6], dtype=float32)},
#  {'predictions': array([116973.29], dtype=float32)},
#  {'predictions': array([314617.7], dtype=float32)},
#  {'predictions': array([204075.11], dtype=float32)},
#  {'predictions': array([115154.664], dtype=float32)},
#  {'predictions': array([218589.88], dtype=float32)},
#  {'predictions': array([127281.02], dtype=float32)},
#  {'predictions': array([137636.39], dtype=float32)},
#  {'predictions': array([211206.02], dtype=float32)},
#  {'predictions': array([113115.51], dtype=float32)},
#  {'predictions': array([151934.34], dtype=float32)},
#  {'predictions': array([269985.78], dtype=float32)},
#  {'predictions': array([265070.53], dtype=float32)},
#  {'predictions': array([195824.25], dtype=float32)},
#  {'predictions': array([182193.45], dtype=float32)},
#  {'predictions': array([212444.11], dtype=float32)},
#  {'predictions': array([141086.78], dtype=float32)},
#  {'predictions': array([111745.9], dtype=float32)},
#  {'predictions': array([213664.39], dtype=float32)},
#  {'predictions': array([121494.92], dtype=float32)},
#  {'predictions': array([225630.78], dtype=float32)},
#  {'predictions': array([152099.42], dtype=float32)},
#  {'predictions': array([135530.31], dtype=float32)},
#  {'predictions': array([296403.6], dtype=float32)},
#  {'predictions': array([130252.18], dtype=float32)},
#  {'predictions': array([205146.69], dtype=float32)},
#  {'predictions': array([107642.31], dtype=float32)},
#  {'predictions': array([209847.52], dtype=float32)},
#  {'predictions': array([203070.77], dtype=float32)},
#  {'predictions': array([142865.11], dtype=float32)},
#  {'predictions': array([129072.22], dtype=float32)},
#  {'predictions': array([321956.84], dtype=float32)},
#  {'predictions': array([161132.98], dtype=float32)},
#  {'predictions': array([257261.6], dtype=float32)},
#  {'predictions': array([147161.5], dtype=float32)},
#  {'predictions': array([129629.99], dtype=float32)},
#  {'predictions': array([241148.34], dtype=float32)},
#  {'predictions': array([196994.62], dtype=float32)},
#  {'predictions': array([162165.9], dtype=float32)},
#  {'predictions': array([179973.06], dtype=float32)},
#  {'predictions': array([154912.4], dtype=float32)},
#  {'predictions': array([320472.53], dtype=float32)},
#  {'predictions': array([169358.25], dtype=float32)},
#  {'predictions': array([171059.56], dtype=float32)},
#  {'predictions': array([129340.9], dtype=float32)},
#  {'predictions': array([220704.66], dtype=float32)},
#  {'predictions': array([267914.97], dtype=float32)},
#  {'predictions': array([127154.9], dtype=float32)},
#  {'predictions': array([158821.81], dtype=float32)},
#  {'predictions': array([185984.94], dtype=float32)},
#  {'predictions': array([177704.1], dtype=float32)},
#  {'predictions': array([269851.4], dtype=float32)},
#  {'predictions': array([178805.88], dtype=float32)},
#  {'predictions': array([102515.06], dtype=float32)},
#  {'predictions': array([151295.48], dtype=float32)},
#  {'predictions': array([137485.36], dtype=float32)},
#  {'predictions': array([245541.17], dtype=float32)},
#  {'predictions': array([199105.53], dtype=float32)},
#  {'predictions': array([256593.88], dtype=float32)},
#  {'predictions': array([437366.88], dtype=float32)},
#  {'predictions': array([233843.36], dtype=float32)},
#  {'predictions': array([161989.08], dtype=float32)},
#  {'predictions': array([84192.695], dtype=float32)},
#  {'predictions': array([121479.125], dtype=float32)},
#  {'predictions': array([128889.29], dtype=float32)},
#  {'predictions': array([356003.16], dtype=float32)},
#  {'predictions': array([168468.03], dtype=float32)},
#  {'predictions': array([312240.97], dtype=float32)},
#  {'predictions': array([144354.38], dtype=float32)},
#  {'predictions': array([185526.06], dtype=float32)},
#  {'predictions': array([296389.97], dtype=float32)},
#  {'predictions': array([88697.85], dtype=float32)},
#  {'predictions': array([137371.27], dtype=float32)},
#  {'predictions': array([161478.5], dtype=float32)},
#  {'predictions': array([113190.15], dtype=float32)},
#  {'predictions': array([174669.47], dtype=float32)},
#  {'predictions': array([241073.25], dtype=float32)},
#  {'predictions': array([225333.1], dtype=float32)},
#  {'predictions': array([129083.55], dtype=float32)},
#  {'predictions': array([154349.62], dtype=float32)},
#  {'predictions': array([136828.8], dtype=float32)},
#  {'predictions': array([152138.55], dtype=float32)},
#  {'predictions': array([117003.93], dtype=float32)},
#  {'predictions': array([168968.08], dtype=float32)},
#  {'predictions': array([314447.28], dtype=float32)},
#  {'predictions': array([128556.93], dtype=float32)},
#  {'predictions': array([269295.78], dtype=float32)},
#  {'predictions': array([124498.86], dtype=float32)},
#  {'predictions': array([232093.], dtype=float32)},
#  {'predictions': array([121677.21], dtype=float32)},
#  {'predictions': array([288379.6], dtype=float32)},
#  {'predictions': array([132933.84], dtype=float32)},
#  {'predictions': array([137877.52], dtype=float32)},
#  {'predictions': array([368268.4], dtype=float32)},
#  {'predictions': array([373431.88], dtype=float32)},
#  {'predictions': array([284434.5], dtype=float32)},
#  {'predictions': array([230019.62], dtype=float32)},
#  {'predictions': array([143476.6], dtype=float32)},
#  {'predictions': array([125647.02], dtype=float32)},
#  {'predictions': array([129566.02], dtype=float32)},
#  {'predictions': array([222942.47], dtype=float32)},
#  {'predictions': array([235455.08], dtype=float32)},
#  {'predictions': array([342902.97], dtype=float32)},
#  {'predictions': array([108651.8], dtype=float32)},
#  {'predictions': array([233276.5], dtype=float32)},
#  {'predictions': array([301513.03], dtype=float32)},
#  {'predictions': array([302023.97], dtype=float32)},
#  {'predictions': array([171899.9], dtype=float32)},
#  {'predictions': array([121644.734], dtype=float32)},
#  {'predictions': array([187386.33], dtype=float32)},
#  {'predictions': array([94779.42], dtype=float32)},
#  {'predictions': array([255750.48], dtype=float32)},
#  {'predictions': array([241441.6], dtype=float32)},
#  {'predictions': array([550611.1], dtype=float32)},
#  {'predictions': array([201067.1], dtype=float32)},
#  {'predictions': array([196899.53], dtype=float32)},
#  {'predictions': array([218507.47], dtype=float32)},
#  {'predictions': array([192802.31], dtype=float32)},
#  {'predictions': array([156602.27], dtype=float32)},
#  {'predictions': array([192754.1], dtype=float32)},
#  {'predictions': array([163396.55], dtype=float32)},
#  {'predictions': array([110093.414], dtype=float32)},
#  {'predictions': array([227216.2], dtype=float32)},
#  {'predictions': array([173485.55], dtype=float32)},
#  {'predictions': array([413753.22], dtype=float32)},
#  {'predictions': array([117430.63], dtype=float32)},
#  {'predictions': array([226515.19], dtype=float32)},
#  {'predictions': array([139065.12], dtype=float32)},
#  {'predictions': array([174209.81], dtype=float32)},
#  {'predictions': array([240759.03], dtype=float32)},
#  {'predictions': array([237304.16], dtype=float32)},
#  {'predictions': array([134512.27], dtype=float32)},
#  {'predictions': array([139710.36], dtype=float32)},
#  {'predictions': array([278327.47], dtype=float32)},
#  {'predictions': array([349799.47], dtype=float32)},
#  {'predictions': array([166265.14], dtype=float32)},
#  {'predictions': array([198477.17], dtype=float32)},
#  {'predictions': array([170206.14], dtype=float32)},
#  {'predictions': array([245380.64], dtype=float32)},
#  {'predictions': array([211290.33], dtype=float32)},
#  {'predictions': array([184863.11], dtype=float32)},
#  {'predictions': array([311235.66], dtype=float32)},
#  {'predictions': array([193641.97], dtype=float32)},
#  {'predictions': array([113241.586], dtype=float32)},
#  {'predictions': array([272723.28], dtype=float32)},
#  {'predictions': array([228476.19], dtype=float32)},
#  {'predictions': array([165633.88], dtype=float32)},
#  {'predictions': array([130125.1], dtype=float32)},
#  {'predictions': array([264046.62], dtype=float32)},
#  {'predictions': array([175698.22], dtype=float32)},
#  {'predictions': array([243392.94], dtype=float32)},
#  {'predictions': array([110540.63], dtype=float32)},
#  {'predictions': array([137922.72], dtype=float32)},
#  {'predictions': array([256206.88], dtype=float32)},
#  {'predictions': array([392545.97], dtype=float32)},
#  {'predictions': array([136912.06], dtype=float32)},
#  {'predictions': array([229792.3], dtype=float32)},
#  {'predictions': array([240674.12], dtype=float32)},
#  {'predictions': array([104299.72], dtype=float32)},
#  {'predictions': array([163826.19], dtype=float32)},
#  {'predictions': array([168447.16], dtype=float32)},
#  {'predictions': array([187674.53], dtype=float32)},
#  {'predictions': array([238340.84], dtype=float32)},
#  {'predictions': array([149751.9], dtype=float32)},
#  {'predictions': array([158721.47], dtype=float32)},
#  {'predictions': array([139611.61], dtype=float32)},
#  {'predictions': array([131380.98], dtype=float32)},
#  {'predictions': array([267095.03], dtype=float32)},
#  {'predictions': array([143603.2], dtype=float32)},
#  {'predictions': array([241496.78], dtype=float32)},
#  {'predictions': array([135782.5], dtype=float32)},
#  {'predictions': array([384195.78], dtype=float32)},
#  {'predictions': array([190684.8], dtype=float32)},
#  {'predictions': array([210989.34], dtype=float32)},
#  {'predictions': array([168375.6], dtype=float32)},
#  {'predictions': array([111438.82], dtype=float32)},
#  {'predictions': array([195586.31], dtype=float32)},
#  {'predictions': array([120463.3], dtype=float32)},
#  {'predictions': array([227661.88], dtype=float32)},
#  {'predictions': array([165362.4], dtype=float32)},
#  {'predictions': array([223352.1], dtype=float32)},
#  {'predictions': array([209087.81], dtype=float32)},
#  {'predictions': array([232254.16], dtype=float32)},
#  {'predictions': array([348538.84], dtype=float32)},
#  {'predictions': array([108938.414], dtype=float32)},
#  {'predictions': array([170735.44], dtype=float32)},
#  {'predictions': array([221839.69], dtype=float32)},
#  {'predictions': array([216061.69], dtype=float32)},
#  {'predictions': array([268750.34], dtype=float32)},
#  {'predictions': array([300830.9], dtype=float32)},
#  {'predictions': array([232528.47], dtype=float32)},
#  {'predictions': array([221731.12], dtype=float32)},
#  {'predictions': array([227589.33], dtype=float32)},
#  {'predictions': array([131380.4], dtype=float32)},
#  {'predictions': array([208140.28], dtype=float32)},
#  {'predictions': array([250149.28], dtype=float32)},
#  {'predictions': array([108115.71], dtype=float32)},
#  {'predictions': array([246801.66], dtype=float32)},
#  {'predictions': array([124108.055], dtype=float32)},
#  {'predictions': array([208192.81], dtype=float32)},
#  {'predictions': array([212784.66], dtype=float32)},
#  {'predictions': array([133174.61], dtype=float32)},
#  {'predictions': array([248460.31], dtype=float32)},
#  {'predictions': array([221069.38], dtype=float32)},
#  {'predictions': array([97133.58], dtype=float32)},
#  {'predictions': array([248384.47], dtype=float32)},
#  {'predictions': array([153156.02], dtype=float32)},
#  {'predictions': array([89305.88], dtype=float32)},
#  {'predictions': array([191351.56], dtype=float32)},
#  {'predictions': array([204987.16], dtype=float32)},
#  {'predictions': array([134764.44], dtype=float32)},
#  {'predictions': array([115820.32], dtype=float32)},
#  {'predictions': array([167241.6], dtype=float32)},
#  {'predictions': array([243699.94], dtype=float32)},
#  {'predictions': array([183173.88], dtype=float32)},
#  {'predictions': array([145125.25], dtype=float32)},
#  {'predictions': array([116153.28], dtype=float32)},
#  {'predictions': array([128100.945], dtype=float32)},
#  {'predictions': array([242985.69], dtype=float32)},
#  {'predictions': array([210062.66], dtype=float32)},
#  {'predictions': array([141363.69], dtype=float32)},
#  {'predictions': array([257557.25], dtype=float32)},
#  {'predictions': array([255292.03], dtype=float32)},
#  {'predictions': array([295434.22], dtype=float32)},
#  {'predictions': array([248408.5], dtype=float32)},
#  {'predictions': array([145762.4], dtype=float32)},
#  {'predictions': array([234212.9], dtype=float32)},
#  {'predictions': array([169638.2], dtype=float32)},
#  {'predictions': array([48172.098], dtype=float32)},
#  {'predictions': array([204904.03], dtype=float32)},
#  {'predictions': array([159609.58], dtype=float32)},
#  {'predictions': array([98043.35], dtype=float32)},
#  {'predictions': array([275844.75], dtype=float32)},
#  {'predictions': array([123569.98], dtype=float32)},
#  {'predictions': array([169993.31], dtype=float32)},
#  {'predictions': array([102692.04], dtype=float32)},
#  {'predictions': array([235921.94], dtype=float32)},
#  {'predictions': array([147498.25], dtype=float32)},
#  {'predictions': array([141154.], dtype=float32)},
#  {'predictions': array([363710.6], dtype=float32)},
#  {'predictions': array([195265.56], dtype=float32)},
#  {'predictions': array([140035.47], dtype=float32)},
#  {'predictions': array([226916.11], dtype=float32)},
#  {'predictions': array([201274.72], dtype=float32)},
#  {'predictions': array([277269.4], dtype=float32)},
#  {'predictions': array([201565.9], dtype=float32)},
#  {'predictions': array([155014.33], dtype=float32)},
#  {'predictions': array([170872.62], dtype=float32)},
#  {'predictions': array([188928.98], dtype=float32)},
#  {'predictions': array([300147.84], dtype=float32)},
#  {'predictions': array([200035.5], dtype=float32)},
#  {'predictions': array([170235.75], dtype=float32)},
#  {'predictions': array([127038.04], dtype=float32)},
#  {'predictions': array([133480.72], dtype=float32)},
#  {'predictions': array([237565.56], dtype=float32)},
#  {'predictions': array([128748.02], dtype=float32)},
#  {'predictions': array([343209.1], dtype=float32)},
#  {'predictions': array([228233.19], dtype=float32)},
#  {'predictions': array([110812.63], dtype=float32)},
#  {'predictions': array([141806.94], dtype=float32)},
#  {'predictions': array([170620.31], dtype=float32)},
#  {'predictions': array([158275.02], dtype=float32)},
#  {'predictions': array([169251.4], dtype=float32)},
#  {'predictions': array([204491.69], dtype=float32)},
#  {'predictions': array([139616.6], dtype=float32)},
#  {'predictions': array([260145.1], dtype=float32)},
#  {'predictions': array([299526.9], dtype=float32)},
#  {'predictions': array([104804.03], dtype=float32)},
#  {'predictions': array([428276.75], dtype=float32)},
#  {'predictions': array([237698.02], dtype=float32)},
#  {'predictions': array([196174.], dtype=float32)},
#  {'predictions': array([170080.4], dtype=float32)},
#  {'predictions': array([309453.34], dtype=float32)},
#  {'predictions': array([506992.1], dtype=float32)},
#  {'predictions': array([345360.03], dtype=float32)},
#  {'predictions': array([436419.34], dtype=float32)},
#  {'predictions': array([141622.66], dtype=float32)},
#  {'predictions': array([242965.12], dtype=float32)},
#  {'predictions': array([203246.67], dtype=float32)},
#  {'predictions': array([187159.77], dtype=float32)},
#  {'predictions': array([182337.84], dtype=float32)},
#  {'predictions': array([149400.98], dtype=float32)},
#  {'predictions': array([128509.48], dtype=float32)},
#  {'predictions': array([104513.336], dtype=float32)},
#  {'predictions': array([284880.9], dtype=float32)},
#  {'predictions': array([164273.22], dtype=float32)},
#  {'predictions': array([169648.97], dtype=float32)},
#  {'predictions': array([344182.78], dtype=float32)},
#  {'predictions': array([134222.47], dtype=float32)},
#  {'predictions': array([345965.12], dtype=float32)},
#  {'predictions': array([243803.84], dtype=float32)},
#  {'predictions': array([157338.83], dtype=float32)},
#  {'predictions': array([180567.44], dtype=float32)},
#  {'predictions': array([297607.4], dtype=float32)},
#  {'predictions': array([289351.8], dtype=float32)},
#  {'predictions': array([270549.12], dtype=float32)},
#  {'predictions': array([204601.69], dtype=float32)},
#  {'predictions': array([169326.12], dtype=float32)},
#  {'predictions': array([243073.06], dtype=float32)},
#  {'predictions': array([170750.27], dtype=float32)},
#  {'predictions': array([94878.37], dtype=float32)},
#  {'predictions': array([255743.16], dtype=float32)},
#  {'predictions': array([334190.44], dtype=float32)},
#  {'predictions': array([331051.88], dtype=float32)},
#  {'predictions': array([101779.414], dtype=float32)},
#  {'predictions': array([235363.72], dtype=float32)},
#  {'predictions': array([157997.94], dtype=float32)},
#  {'predictions': array([243391.28], dtype=float32)},
#  {'predictions': array([211284.03], dtype=float32)},
#  {'predictions': array([114582.33], dtype=float32)},
#  {'predictions': array([134633.3], dtype=float32)},
#  {'predictions': array([178503.17], dtype=float32)},
#  {'predictions': array([164440.38], dtype=float32)},
#  {'predictions': array([203076.9], dtype=float32)},
#  {'predictions': array([271227.75], dtype=float32)},
#  {'predictions': array([167393.31], dtype=float32)},
#  {'predictions': array([188120.84], dtype=float32)},
#  {'predictions': array([335691.28], dtype=float32)},
#  {'predictions': array([715113.75], dtype=float32)},
#  {'predictions': array([212438.69], dtype=float32)},
#  {'predictions': array([130914.9], dtype=float32)},
#  {'predictions': array([296943.56], dtype=float32)},
#  {'predictions': array([247151.19], dtype=float32)},
#  {'predictions': array([244192.44], dtype=float32)},
#  {'predictions': array([135931.12], dtype=float32)},
#  {'predictions': array([202840.77], dtype=float32)},
#  {'predictions': array([212730.1], dtype=float32)},
#  {'predictions': array([276540.3], dtype=float32)},
#  {'predictions': array([196935.78], dtype=float32)},
#  {'predictions': array([122541.57], dtype=float32)},
#  {'predictions': array([150801.06], dtype=float32)},
#  {'predictions': array([174903.7], dtype=float32)},
#  {'predictions': array([182772.62], dtype=float32)},
#  {'predictions': array([316000.97], dtype=float32)},
#  {'predictions': array([217343.55], dtype=float32)},
#  {'predictions': array([236969.27], dtype=float32)},
#  {'predictions': array([256560.61], dtype=float32)},
#  {'predictions': array([342045.44], dtype=float32)},
#  {'predictions': array([260447.45], dtype=float32)},
#  {'predictions': array([293751.88], dtype=float32)},
#  {'predictions': array([314716.53], dtype=float32)},
#  {'predictions': array([251193.75], dtype=float32)},
#  {'predictions': array([170517.44], dtype=float32)},
#  {'predictions': array([221101.25], dtype=float32)},
#  {'predictions': array([152046.38], dtype=float32)},
#  {'predictions': array([169289.53], dtype=float32)},
#  {'predictions': array([238616.5], dtype=float32)},
#  {'predictions': array([218473.39], dtype=float32)},
#  {'predictions': array([163897.53], dtype=float32)},
#  {'predictions': array([165092.53], dtype=float32)},
#  {'predictions': array([242340.34], dtype=float32)},
#  {'predictions': array([139897.22], dtype=float32)},
#  {'predictions': array([252345.53], dtype=float32)},
#  {'predictions': array([192337.8], dtype=float32)},
#  {'predictions': array([271786.16], dtype=float32)},
#  {'predictions': array([284350.84], dtype=float32)},
#  {'predictions': array([136738.5], dtype=float32)},
#  {'predictions': array([198551.88], dtype=float32)},
#  {'predictions': array([259363.42], dtype=float32)},
#  {'predictions': array([139108.89], dtype=float32)},
#  {'predictions': array([150294.6], dtype=float32)},
#  {'predictions': array([194844.34], dtype=float32)},
#  {'predictions': array([296771.28], dtype=float32)},
#  {'predictions': array([250893.94], dtype=float32)},
#  {'predictions': array([147634.97], dtype=float32)},
#  {'predictions': array([256921.31], dtype=float32)},
#  {'predictions': array([150009.38], dtype=float32)},
#  {'predictions': array([139989.92], dtype=float32)},
#  {'predictions': array([154200.12], dtype=float32)},
#  {'predictions': array([138903.61], dtype=float32)},
#  {'predictions': array([127079.055], dtype=float32)},
#  {'predictions': array([134046.33], dtype=float32)},
#  {'predictions': array([115945.76], dtype=float32)},
#  {'predictions': array([274886.28], dtype=float32)},
#  {'predictions': array([338476.06], dtype=float32)},
#  {'predictions': array([289972.22], dtype=float32)},
#  {'predictions': array([193804.47], dtype=float32)},
#  {'predictions': array([188470.9], dtype=float32)},
#  {'predictions': array([161052.66], dtype=float32)},
#  {'predictions': array([108460.19], dtype=float32)},
#  {'predictions': array([134934.69], dtype=float32)},
#  {'predictions': array([368448.25], dtype=float32)},
#  {'predictions': array([317542.6], dtype=float32)},
#  {'predictions': array([144697.8], dtype=float32)},
#  {'predictions': array([145470.6], dtype=float32)},
#  {'predictions': array([271097.72], dtype=float32)},
#  {'predictions': array([137648.72], dtype=float32)},
#  {'predictions': array([145116.36], dtype=float32)},
#  {'predictions': array([136022.02], dtype=float32)},
#  {'predictions': array([199605.1], dtype=float32)},
#  {'predictions': array([331022.16], dtype=float32)},
#  {'predictions': array([173896.67], dtype=float32)},
#  {'predictions': array([246910.81], dtype=float32)},
#  {'predictions': array([227821.03], dtype=float32)},
#  {'predictions': array([250572.06], dtype=float32)},
#  {'predictions': array([206961.62], dtype=float32)},
#  {'predictions': array([142513.64], dtype=float32)},
#  {'predictions': array([114102.164], dtype=float32)},
#  {'predictions': array([201928.11], dtype=float32)},
#  {'predictions': array([151153.23], dtype=float32)},
#  {'predictions': array([126834.49], dtype=float32)},
#  {'predictions': array([458263.6], dtype=float32)},
#  {'predictions': array([143735.88], dtype=float32)},
#  {'predictions': array([143463.44], dtype=float32)},
#  {'predictions': array([283661.16], dtype=float32)},
#  {'predictions': array([112182.99], dtype=float32)},
#  {'predictions': array([283879.72], dtype=float32)},
#  {'predictions': array([184045.66], dtype=float32)},
#  {'predictions': array([338100.6], dtype=float32)},
#  {'predictions': array([206961.39], dtype=float32)},
#  {'predictions': array([156504.12], dtype=float32)},
#  {'predictions': array([180366.69], dtype=float32)},
#  {'predictions': array([211923.56], dtype=float32)},
#  {'predictions': array([195429.27], dtype=float32)},
#  {'predictions': array([281695.72], dtype=float32)},
#  {'predictions': array([100502.914], dtype=float32)},
#  {'predictions': array([273959.1], dtype=float32)},
#  {'predictions': array([236773.06], dtype=float32)},
#  {'predictions': array([221813.7], dtype=float32)},
#  {'predictions': array([257825.12], dtype=float32)},
#  {'predictions': array([311580.72], dtype=float32)},
#  {'predictions': array([200088.69], dtype=float32)},
#  {'predictions': array([224070.22], dtype=float32)},
#  {'predictions': array([169452.88], dtype=float32)},
#  {'predictions': array([421721.88], dtype=float32)},
#  {'predictions': array([136480.16], dtype=float32)},
#  {'predictions': array([144919.25], dtype=float32)},
#  {'predictions': array([175706.06], dtype=float32)},
#  {'predictions': array([119372.58], dtype=float32)},
#  {'predictions': array([177994.17], dtype=float32)},
#  {'predictions': array([374100.03], dtype=float32)},
#  {'predictions': array([190825.88], dtype=float32)},
#  {'predictions': array([161540.4], dtype=float32)},
#  {'predictions': array([292731.03], dtype=float32)},
#  {'predictions': array([136624.78], dtype=float32)},
#  {'predictions': array([249753.5], dtype=float32)},
#  {'predictions': array([202649.03], dtype=float32)},
#  {'predictions': array([290541.7], dtype=float32)},
#  {'predictions': array([167840.19], dtype=float32)},
#  {'predictions': array([217887.2], dtype=float32)},
#  {'predictions': array([219381.72], dtype=float32)},
#  {'predictions': array([329104.47], dtype=float32)},
#  {'predictions': array([99826.49], dtype=float32)},
#  {'predictions': array([216807.58], dtype=float32)},
#  {'predictions': array([168822.28], dtype=float32)},
#  {'predictions': array([112256.68], dtype=float32)},
#  {'predictions': array([344806.88], dtype=float32)},
#  {'predictions': array([156669.7], dtype=float32)},
#  {'predictions': array([120770.57], dtype=float32)},
#  {'predictions': array([344352.66], dtype=float32)},
#  {'predictions': array([505118.7], dtype=float32)},
#  {'predictions': array([191288.53], dtype=float32)},
#  {'predictions': array([120268.086], dtype=float32)},
#  {'predictions': array([181149.1], dtype=float32)},
#  {'predictions': array([232693.9], dtype=float32)},
#  {'predictions': array([143036.44], dtype=float32)},
#  {'predictions': array([128371.164], dtype=float32)},
#  {'predictions': array([500721.8], dtype=float32)},
#  {'predictions': array([319333.03], dtype=float32)},
#  {'predictions': array([257248.31], dtype=float32)},
#  {'predictions': array([228237.16], dtype=float32)},
#  {'predictions': array([241477.27], dtype=float32)},
#  {'predictions': array([130597.57], dtype=float32)},
#  {'predictions': array([206015.62], dtype=float32)},
#  {'predictions': array([99852.79], dtype=float32)},
#  {'predictions': array([271706.47], dtype=float32)},
#  {'predictions': array([86059.58], dtype=float32)},
#  {'predictions': array([99754.32], dtype=float32)},
#  {'predictions': array([245319.05], dtype=float32)},
#  {'predictions': array([272421.16], dtype=float32)},
#  {'predictions': array([207395.3], dtype=float32)},
#  {'predictions': array([421619.34], dtype=float32)},
#  {'predictions': array([116941.484], dtype=float32)},
#  {'predictions': array([242129.53], dtype=float32)},
#  {'predictions': array([168055.89], dtype=float32)},
#  {'predictions': array([157609.12], dtype=float32)},
#  {'predictions': array([293531.9], dtype=float32)},
#  {'predictions': array([206998.], dtype=float32)},
#  {'predictions': array([108589.85], dtype=float32)},
#  {'predictions': array([133821.48], dtype=float32)},
#  {'predictions': array([258992.31], dtype=float32)},
#  {'predictions': array([292336.25], dtype=float32)},
#  {'predictions': array([196002.28], dtype=float32)},
#  {'predictions': array([125007.07], dtype=float32)},
#  {'predictions': array([141359.02], dtype=float32)},
#  {'predictions': array([176482.94], dtype=float32)},
#  {'predictions': array([189421.12], dtype=float32)},
#  {'predictions': array([293924.47], dtype=float32)},
#  {'predictions': array([180001.61], dtype=float32)},
#  {'predictions': array([349790.16], dtype=float32)},
#  {'predictions': array([159993.97], dtype=float32)},
#  {'predictions': array([104107.02], dtype=float32)},
#  {'predictions': array([99558.23], dtype=float32)},
#  {'predictions': array([740786.25], dtype=float32)},
#  {'predictions': array([203719.61], dtype=float32)},
#  {'predictions': array([185116.19], dtype=float32)},
#  {'predictions': array([269201.66], dtype=float32)},
#  {'predictions': array([231133.05], dtype=float32)},
#  {'predictions': array([154234.3], dtype=float32)},
#  {'predictions': array([141984.73], dtype=float32)},
#  {'predictions': array([142948.34], dtype=float32)},
#  {'predictions': array([125187.13], dtype=float32)},
#  {'predictions': array([226227.94], dtype=float32)},
#  {'predictions': array([240222.16], dtype=float32)},
#  {'predictions': array([111756.96], dtype=float32)},
#  {'predictions': array([672219.2], dtype=float32)},
#  {'predictions': array([249267.55], dtype=float32)},
#  {'predictions': array([212540.66], dtype=float32)},
#  {'predictions': array([228057.], dtype=float32)},
#  {'predictions': array([285906.6], dtype=float32)},
#  {'predictions': array([280885.34], dtype=float32)},
#  {'predictions': array([159837.66], dtype=float32)},
#  {'predictions': array([277127.16], dtype=float32)},
#  {'predictions': array([147867.8], dtype=float32)},
#  {'predictions': array([117987.336], dtype=float32)},
#  {'predictions': array([223023.33], dtype=float32)},
#  {'predictions': array([118118.13], dtype=float32)},
#  {'predictions': array([225069.19], dtype=float32)},
#  {'predictions': array([125599.234], dtype=float32)},
#  {'predictions': array([236572.19], dtype=float32)},
#  {'predictions': array([203756.06], dtype=float32)},
#  {'predictions': array([214832.44], dtype=float32)},
#  {'predictions': array([206512.11], dtype=float32)},
#  {'predictions': array([248889.97], dtype=float32)},
#  {'predictions': array([184244.56], dtype=float32)},
#  {'predictions': array([296301.28], dtype=float32)},
#  {'predictions': array([131876.5], dtype=float32)},
#  {'predictions': array([272824.53], dtype=float32)},
#  {'predictions': array([136363.64], dtype=float32)},
#  {'predictions': array([206573.72], dtype=float32)},
#  {'predictions': array([205804.75], dtype=float32)},
#  {'predictions': array([165476.56], dtype=float32)},
#  {'predictions': array([114953.77], dtype=float32)},
#  {'predictions': array([241267.81], dtype=float32)},
#  {'predictions': array([303588.28], dtype=float32)},
#  {'predictions': array([133114.94], dtype=float32)},
#  {'predictions': array([106757.74], dtype=float32)},
#  {'predictions': array([183302.16], dtype=float32)},
#  {'predictions': array([174572.97], dtype=float32)},
#  {'predictions': array([653513.1], dtype=float32)},
#  {'predictions': array([139596.5], dtype=float32)},
#  {'predictions': array([191335.2], dtype=float32)},
#  {'predictions': array([110732.82], dtype=float32)},
#  {'predictions': array([375114.53], dtype=float32)},
#  {'predictions': array([98663.12], dtype=float32)},
#  {'predictions': array([116339.43], dtype=float32)},
#  {'predictions': array([139808.11], dtype=float32)},
#  {'predictions': array([151373.42], dtype=float32)},
#  {'predictions': array([239655.44], dtype=float32)},
#  {'predictions': array([294646.16], dtype=float32)},
#  {'predictions': array([141501.1], dtype=float32)},
#  {'predictions': array([214253.98], dtype=float32)},
#  {'predictions': array([379833.22], dtype=float32)},
#  {'predictions': array([126496.02], dtype=float32)},
#  {'predictions': array([182642.22], dtype=float32)},
#  {'predictions': array([166775.9], dtype=float32)},
#  {'predictions': array([433335.53], dtype=float32)},
#  {'predictions': array([110230.836], dtype=float32)},
#  {'predictions': array([229420.69], dtype=float32)},
#  {'predictions': array([152520.53], dtype=float32)},
#  {'predictions': array([189075.62], dtype=float32)},
#  {'predictions': array([133438.61], dtype=float32)},
#  {'predictions': array([156186.03], dtype=float32)},
#  {'predictions': array([221908.28], dtype=float32)},
#  {'predictions': array([127648.69], dtype=float32)},
#  {'predictions': array([192004.], dtype=float32)},
#  {'predictions': array([157914.16], dtype=float32)},
#  {'predictions': array([198130.94], dtype=float32)},
#  {'predictions': array([167215.34], dtype=float32)},
#  {'predictions': array([241687.44], dtype=float32)},
#  {'predictions': array([208943.88], dtype=float32)},
#  {'predictions': array([109547.73], dtype=float32)},
#  {'predictions': array([132087.94], dtype=float32)},
#  {'predictions': array([133672.03], dtype=float32)},
#  {'predictions': array([198191.12], dtype=float32)},
#  {'predictions': array([346330.53], dtype=float32)},
#  {'predictions': array([225489.03], dtype=float32)},
#  {'predictions': array([128675.11], dtype=float32)},
#  {'predictions': array([403541.97], dtype=float32)},
#  {'predictions': array([132220.58], dtype=float32)},
#  {'predictions': array([244895.9], dtype=float32)},
#  {'predictions': array([118693.79], dtype=float32)},
#  {'predictions': array([141314.44], dtype=float32)},
#  {'predictions': array([505274.2], dtype=float32)},
#  {'predictions': array([149303.92], dtype=float32)},
#  {'predictions': array([185783.64], dtype=float32)},
#  {'predictions': array([110244.99], dtype=float32)},
#  {'predictions': array([257609.94], dtype=float32)},
#  {'predictions': array([235132.81], dtype=float32)},
#  {'predictions': array([287659.25], dtype=float32)},
#  {'predictions': array([199131.73], dtype=float32)},
#  {'predictions': array([199324.88], dtype=float32)},
#  {'predictions': array([137740.84], dtype=float32)},
#  {'predictions': array([179344.5], dtype=float32)},
#  {'predictions': array([137856.2], dtype=float32)},
#  {'predictions': array([233066.75], dtype=float32)},
#  {'predictions': array([131818.53], dtype=float32)},
#  {'predictions': array([111877.516], dtype=float32)},
#  {'predictions': array([120976.586], dtype=float32)},
#  {'predictions': array([216372.69], dtype=float32)},
#  {'predictions': array([154062.6], dtype=float32)},
#  {'predictions': array([331022.47], dtype=float32)},
#  {'predictions': array([313235.78], dtype=float32)},
#  {'predictions': array([271612.34], dtype=float32)},
#  {'predictions': array([230810.4], dtype=float32)},
#  {'predictions': array([426381.72], dtype=float32)},
#  {'predictions': array([434553.28], dtype=float32)},
#  {'predictions': array([130310.79], dtype=float32)},
#  {'predictions': array([208785.47], dtype=float32)},
#  {'predictions': array([125215.12], dtype=float32)},
#  {'predictions': array([167699.47], dtype=float32)},
#  {'predictions': array([281528.9], dtype=float32)},
#  {'predictions': array([189388.42], dtype=float32)},
#  {'predictions': array([105814.75], dtype=float32)},
#  {'predictions': array([313967.53], dtype=float32)},
#  {'predictions': array([254217.92], dtype=float32)},
#  {'predictions': array([260852.33], dtype=float32)},
#  {'predictions': array([90286.9], dtype=float32)},
#  {'predictions': array([475311.16], dtype=float32)},
#  {'predictions': array([232384.1], dtype=float32)},
#  {'predictions': array([125006.59], dtype=float32)},
#  {'predictions': array([167804.72], dtype=float32)},
#  {'predictions': array([222495.66], dtype=float32)},
#  {'predictions': array([167439.67], dtype=float32)},
#  {'predictions': array([194111.16], dtype=float32)},
#  {'predictions': array([156276.97], dtype=float32)},
#  {'predictions': array([151218.4], dtype=float32)},
#  {'predictions': array([180853.31], dtype=float32)},
#  {'predictions': array([131592.66], dtype=float32)},
#  {'predictions': array([234981.75], dtype=float32)},
#  {'predictions': array([119452.49], dtype=float32)},
#  {'predictions': array([238932.4], dtype=float32)},
#  {'predictions': array([225909.9], dtype=float32)},
#  {'predictions': array([119381.195], dtype=float32)},
#  {'predictions': array([220367.16], dtype=float32)},
#  {'predictions': array([163183.03], dtype=float32)},
#  {'predictions': array([162362.81], dtype=float32)},
#  {'predictions': array([147660.36], dtype=float32)},
#  {'predictions': array([208573.6], dtype=float32)},
#  ...]

# %% [markdown]
# ** Calculate the RMSE. You should be able to get around 100,000 RMSE (remember that this is in the same units as the label.) Do this manually or use [sklearn.metrics](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html) **

# %%
final_preds = []
for pred in predictions:
    final_preds.append(pred['predictions'])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,final_preds)**0.5
# Out:
# 77561.38736978068

# %%
from sklearn import metrics

# %%
import numpy as np

# %%
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,final_preds)))
# Out:
# RMSE: 77561.38736978068

# %% [markdown]
# # Great Job!
